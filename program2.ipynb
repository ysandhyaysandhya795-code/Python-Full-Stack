# %%
a = [1,10,30,9,60,28,25]
b = list(filter(lambda x: x%2 ==0,a))
print(b)
# Out:
# [10, 30, 60, 28]

# %%
a = [1,10,30,9,60,28,25]
b = list(filter(lambda x: x%2 ==0,a))
c = list(map(lambda x: x**2,a))
print(b)
print(c)
# Out:
# [10, 30, 60, 28]
# [1, 100, 900, 81, 3600, 784, 625]

# %%
def fact(n): 
     if n ==0 or n==1:
     
         return 1
     return n *fact(n-1)
print(fact(8))
# Out:
# 40320

# %%
s = {1,2,3,4,4,3}

s.add(5)
print(s)
# Out:
# {1, 2, 3, 4, 5}

# %%
s = {1,2,3,4,4,3}
s.add(5)

s.remove(5)

print(s)
# Out:
# {1, 2, 3, 4}

# %%
s = {1,2,3,4,4,3}
s.add(5)

s.remove(5)
s.discard(99)

print(s)
# Out:
# {1, 2, 3, 4}

# %%
s = {1,2,3,4,4,3}
s.add(5)

s.remove(5)
s.discard(99)
s.pop()

print(s)
# Out:
# {2, 3, 4}

# %%
a = {1,2,3,4}
b = {3,4,5,6}

print(a,b)
# Out:
# {1, 2, 3, 4} {3, 4, 5, 6}

# %%
s = "python programming"
count=0
for i in s:
    if i in 'aeiouAEIOU':
        count += 1
print(count)
# Out:
# 4

# %%
try:
    num = int(input("enter a number:"))
            
    result = 100/num
    print(result)

except zerodivisionerror:
    print("error: enter a valid number")
else:
    print("success:", result)
finally:
    print("excution completed")
# Out:
# enter a number: 123
